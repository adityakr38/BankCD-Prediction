# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key1": "value1", "key2": "value2"})

# %%
d2.key1
# Out:
# 'value1'

# %%
#ensure annotation demo

def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_product(x=2, y="3")
#
# File /opt/anaconda3/envs/MLProject/lib/python3.11/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x1073b7880> does not match annotation type <class 'int'>

# %%
import pandas as pd

df_data = pd.read_csv("/Users/adityakumar/BankCD-Prediction/artifacts/data_ingestion/processed_train.csv")
pd.set_option('display.max_columns', None)
df_data.head()
# Out:
#    default  balance  housing  loan   contact  day  duration  campaign  pdays  \
# 0        0    11924        0     0  0.217754   13      4102      32.0    144
# 1        0      398        1     0  0.232184   20        66       4.0     15
# 2        0     2177        1     0  0.217754   19        10       3.0    465
# 3        0    26673        1     0  0.232184    6      3902      17.0    396
# 4        0     6358        0     1  0.217754   15      3563      28.0    314
#
#    previous  poutcome  cd  age_bin_Medium  age_bin_High  job_blue-collar  \
# 0       8.0  0.232275   1           False         False            False
# 1       4.0  0.223617   1           False         False            False
# 2       4.0  0.232275   0           False          True            False
# 3       6.0  0.223617   1            True         False            False
# 4      24.0  0.232275   0            True         False            False
#
#    job_entrepreneur  job_housemaid  job_management  job_retired  \
# 0             False          False           False        False
# 1             False           True           False        False
# 2             False          False           False        False
# 3             False           True           False        False
# 4              True          False           False        False
#
#    job_self-employed  job_services  job_student  job_technician  \
# 0              False         False        False           False
# 1              False         False        False           False
# 2              False         False        False           False
# 3              False         False        False           False
# 4              False         False        False           False
#
#    job_unemployed  job_unknown  marital_married  marital_single  \
# 0           False        False            False            True
# 1           False        False            False           False
# 2           False         True             True           False
# 3           False        False             True           False
# 4           False        False            False            True
#
#    education_Secondary  education_Tertiary  education_Unknown  \
# 0                False                True              False
# 1                False               False              False
# 2                False               False               True
# 3                False                True              False
# 4                False               False              False
#
#    generation_millenials  generation_older boomers  \
# 0                   True                     False
# 1                   True                     False
# 2                  False                     False
# 3                  False                      True
# 4                   True                     False
#
#    generation_silent generation  generation_younger boomers  month_aug  \
# 0                         False                       False      False
# 1                         False                       False      False
# 2                          True                       False      False
# 3                         False                       False      False
# 4                         False                       False      False
#
#    month_dec  month_feb  month_jan  month_jul  month_jun  month_mar  \
# 0      False      False       True      False      False      False
# 1      False      False      False      False       True      False
# 2      False      False      False      False      False      False
# 3      False      False      False      False      False      False
# 4      False       True      False      False      False      False
#
#    month_may  month_nov  month_oct  month_sep
# 0      False      False      False      False
# 1      False      False      False      False
# 2       True      False      False      False
# 3      False      False       True      False
# 4      False      False      False      False

# %%
df_data.shape
# Out:
# (35940, 45)

# %%
df_data.columns
# Out:
# Index(['default', 'balance', 'housing', 'loan', 'contact', 'day', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'cd', 'age_bin_Medium',
#        'age_bin_High', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_married', 'marital_single', 'education_Secondary',
#        'education_Tertiary', 'education_Unknown', 'generation_millenials',
#        'generation_older boomers', 'generation_silent generation',
#        'generation_younger boomers', 'month_aug', 'month_dec', 'month_feb',
#        'month_jan', 'month_jul', 'month_jun', 'month_mar', 'month_may',
#        'month_nov', 'month_oct', 'month_sep'],
#       dtype='object')
